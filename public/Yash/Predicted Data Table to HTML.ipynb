# %%
import pandas as pd

# %%
Predicted_Info_2 = pd.read_csv("Predicted_Info_2.csv")

# %%
Predicted_Info_2
# Out:
#     Ticker                 name                  sector  Opening_6_28_21  \
# 0      MMM           3M Company             Industrials         195.7600
# 1      ABT  Abbott Laboratories             Health Care         112.9900
# 2     ABBV          AbbVie Inc.             Health Care         113.2600
# 3     ABMD              Abiomed             Health Care         312.5000
# 4      ACN            Accenture  Information Technology         294.4400
# ..     ...                  ...                     ...              ...
# 497    YUM      Yum! Brands Inc  Consumer Discretionary         116.9000
# 498   ZBRA   Zebra Technologies  Information Technology         511.9200
# 499    ZBH        Zimmer Biomet             Health Care         166.1000
# 500   ZION        Zions Bancorp              Financials          55.4686
# 501    ZTS               Zoetis             Health Care         187.3400
#
#      High_6_28_21  Low_6_28_21  Closing_6_28_21  Volume_6_28_21  \
# ...

# %%
Predicted_Info_2_html = Predicted_Info_2.to_html("Predicted_Info_2.html")

# %%
print(Predicted_Info_2_html)
# Out:
# None
